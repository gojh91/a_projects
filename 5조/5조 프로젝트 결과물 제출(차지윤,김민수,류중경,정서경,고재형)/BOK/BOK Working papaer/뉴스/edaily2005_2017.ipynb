# %% [markdown]
# # 각 csv마다 중복 검사

# %%
import pandas as pd

# %%
list_a = [
    "C:\\Users\\student\\Downloads\\edaily2005(1_8).csv",
    "C:\\Users\\student\\Downloads\\edaily2006(1_3).csv",
    "C:\\Users\\student\\Downloads\\edaily2006(4)_2007.csv",
    "C:\\Users\\student\\Downloads\\edaily2008(7_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2009_2010(1_11).csv",
    "C:\\Users\\student\\Downloads\\edaily2010(12).csv",
    "C:\\Users\\student\\Downloads\\edaily2011_2012(7).csv",
    "C:\\Users\\student\\Downloads\\edaily2012(6_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2014(1_8).csv",
    "C:\\Users\\student\\Downloads\\edaily2014(9_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2015(8_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2016(1_4).csv",
    "C:\\Users\\student\\Downloads\\edaily2016(5_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2017.csv"
]

# %%
list_c = [
    "C:\\Users\\student\\Downloads\\test\\edaily2005(1_8).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2006(1_3).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2006(4)_2007.csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2008(7_12).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2009_2010(1_11).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2010(12).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2011_2012(7).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2012(6_12).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2014(1_8).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2014(9_12).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2015(8_12).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2016(1_4).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2016(5_12).csv",
    "C:\\Users\\student\\Downloads\\test\\edaily2017.csv"
]

# %%
for list_b in list_a:
    df = pd.read_csv(list_b)
    df1 = df1.append 
    df = df.drop_duplicates()
    df.to_csv(list_c[list_a.index(list_b)], mode='a', header=True)

# %% [markdown]
# # 하나로 합친 후 중복검사

# %%
import pandas as pd

# %%
list_a = [
    "C:\\Users\\student\\Downloads\\edaily2005(1_8).csv",
    "C:\\Users\\student\\Downloads\\edaily2006(1_3).csv",
    "C:\\Users\\student\\Downloads\\edaily2006(4)_2007.csv",
    "C:\\Users\\student\\Downloads\\edaily2008(7_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2009_2010(1_11).csv",
    "C:\\Users\\student\\Downloads\\edaily2010(12).csv",
    "C:\\Users\\student\\Downloads\\edaily2011_2012(7).csv",
    "C:\\Users\\student\\Downloads\\edaily2012(6_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2014(1_8).csv",
    "C:\\Users\\student\\Downloads\\edaily2014(9_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2015(8_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2016(1_4).csv",
    "C:\\Users\\student\\Downloads\\edaily2016(5_12).csv",
    "C:\\Users\\student\\Downloads\\edaily2017.csv"
]

# %%
def date_format(d):
    d = str(d).replace('-', '.')
    
    yyyy = int(d.split('.')[0]) 
    mm = int(d.split('.')[1])
    dd = int(d.split('.')[2])

    this_date= dt.date(yyyy, mm, dd)
    return this_date

# %%
df1 = pd.DataFrame()
for list_b in list_a:
    df = pd.read_csv(list_b)
    df = df[df['content'] != '[ [이데일리 증권시장부], ]'] #해당 값 제거
    df1 = df1.append(df)

df1 = df1.drop_duplicates()

df1.to_csv("C:\\Users\\student\\Downloads\\test.csv", mode='a', header=True)

# %%
df1
# Out:
#                                                 content  \
# 0     [ [edaily 하정민기자] 앞으론 세계의 어떤 투자대상도 과거처럼 두 자리수 수...
# 1     [ [edaily 증권부] (단위=% %P)국고채(3년)3.38+0.10회사채(3년...
# 2     [ [edaily 하정민기자] 연방준비제도이사회(FRB)의 금리인상 기조는 올해 내...
# 3     [ [edaily 이학선기자] 채권수익률이 13일 콜금리 동결 영향으로 하락폭을 축...
# 4     [ [edaily 하정민기자] 작년 중국 소매매출이 전년비 13% 증가한 5조300...
# 5     [ [edaily 김수헌기자] LG화학( ) 노기호 사장은 올해 3대 경영방침으로 ...
# 6     [ [edaily 이승우기자] 국채선물이 6일 장기물 약세 여파로 하락 마감했다. ...
# 7     [ [edaily 이승우기자] 국채선물이 13일 한국은행의 콜금리 동결 여파로 급락...
# 8     [ [edaily 이진우기자] 채권값이 어제보다 더 크게 폭락했다. 오전에는 상승세...
# 9     [ [edaily 김상욱기자] 디지털시대를 맞아 군 위성TV 방송이 실시되고 RH(...
# 10    [ [edaily 하정민기자] 새해들어 펼쳐진 달러 강세는 `반짝 랠리`에 불과하다...
# 11    [ [edaily 김현동기자] 올해 금융권의 여·수신은 상호저축은행을 비롯한 서민금...
# 12    [ [edaily 오상용기자] 올해 미국의 에너지 업체와 원자재 업체들은 실적 호조...
# 13    [ [edaily 권소현기자] 삼성증권이 조선업종에 대해 올해 긍정적인 변화를 보이...
# 14    [ [edaily 이정훈기자] 어차피 콜금리 인하를 생각하고 있다면 가급적 빨리 내...
# 15    [ [뉴욕=edaily 정명수특파원] 미국 연방준비제도이사회의 에드워드 그램리치 이...
# ...
