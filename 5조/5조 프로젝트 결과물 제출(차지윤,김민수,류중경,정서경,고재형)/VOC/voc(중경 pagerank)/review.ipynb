# %%
import pandas as pd
import gzip

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

df = getDF('meta_Electronics.json.gz')

# %%
data5= pd.read_json('reviews_Electronics.json',lines=True)

# %%
data5
# Out:
#                asin   helpful  overall  \
# 0        0132793040    [1, 1]        5
# 1        0321732944    [0, 0]        5
# 2        0439886341    [1, 1]        1
# 3        0439886341    [1, 1]        3
# 4        0439886341    [4, 4]        1
# 5        0511189877    [0, 0]        5
# 6        0511189877    [1, 1]        2
# 7        0511189877    [0, 1]        5
# 8        0511189877    [0, 0]        5
# 9        0511189877    [0, 0]        5
# 10       0511189877    [0, 1]        5
# 11       0528881469    [0, 0]        5
# 12       0528881469    [0, 0]        1
# 13       0528881469    [0, 0]        5
# 14       0528881469  [12, 15]        1
# 15       0528881469  [21, 22]        4
# 16       0528881469  [43, 45]        3
# 17       0528881469   [9, 10]        2
# 18       0528881469  [23, 32]        2
# 19       0528881469    [1, 1]        4
# 20       0528881469  [12, 12]        5
# 21       0528881469    [1, 2]        4
# 22       0528881469    [5, 7]        5
# ...

# %%
meta= pd.read_csv('meta_ele.csv')

# %%
meta.fillna(0)

# %%
temp = meta[meta['categories'].str.contains(r'^(?=.*camera)', na=False)]

# %%
temp = meta[meta['title'].str.contains(r'^(?=.*Nikon)|(?=.*Fuji)|(?=.*Minolta)|(?=.*Sony)|(?=.*Olympus)|(?=.*Digital)|(?=.*DSLR)', na=False)]

# %%
data1 = temp.loc[temp.price >= 50,:]

# %%
meta_list = data1.asin.tolist()

# %%
data = data5.loc[data5.asin.isin(meta_list),:]

# %%
meta_list = temp.asin.tolist()

# %%
data = data5.loc[data5.asin.isin(meta_list),:]

# %%
data = data.reset_index()

# %%
data = data.drop(columns = 'index')

# %%
data.to_csv('reviews.csv')

# %%
import pandas as pd
data = pd.read_csv('review_start.csv', index_col= 0)

# %%
data
# Out:
#               asin   helpful  overall  \
# 0       7040034018    [0, 0]        4
# 1       7040034018    [7, 7]        5
# 2       7040034018    [5, 5]        5
# 3       7040034018    [2, 2]        5
# 4       7040034018    [0, 0]        5
# 5       7040034018    [2, 2]        2
# 6       7040034018    [0, 0]        5
# 7       7040034018    [0, 1]        4
# 8       7040034018    [3, 3]        4
# 9       B00000J46I    [0, 3]        1
# 10      B00000J48G    [6, 8]        4
# 11      B00000J48G  [91, 93]        4
# 12      B00000J48G    [1, 1]        4
# 13      B00000J48G  [23, 24]        4
# 14      B00000J48G    [4, 4]        5
# 15      B00000J48G  [23, 25]        4
# 16      B00000J48G    [0, 0]        1
# 17      B00000J48G    [3, 4]        2
# 18      B00000J48G  [32, 37]        5
# 19      B00000J48G  [14, 14]        5
# 20      B00000J48G    [1, 1]        4
# 21      B00000J48G   [8, 12]        3
# 22      B00000J48G    [8, 8]        4
# ...

# %%
data= data.drop(columns = 'review_sent')

# %%
import nltk

# %%
import numpy as np

# %%
def sentnizer(text):
    sent_text =[]
    for idx in text: 
        try:
            temp=nltk.sent_tokenize(idx)
            sent_text.append(temp)
        except:
            sent_text.append(np.NaN)
            pass
    return sent_text

# %%
sent_text = sentnizer(data.reviewText)

# %%
len(data.reviewText)

# %%
sent_text

# %%
data.merge(sent_text, how='inner')

# %%
data

# %%
sent_text= pd.DataFrame(sent_text)

# %%
sent_text.to_csv('sent_text.csv', index=False, header=False)

# %%
len(sent_text)

# %%
len(data)

# %%
nltk.sent_tokenize(data.reviewText[0]).join

# %%
sent_text_df = pd.DataFrame(data={'sent_text' : sent_text})

# %%
len(sent_text_df)

# %%
sent_text_df

# %%
pd.concat([data,sent_text_df])

# %%
data_1= pd.concat([data,sent_text_df], axis=1)

# %%
data_1.to_csv('data_v1.csv')

# %%
from nltk.corpus import comparative_sentences

# %%
def ctsents(text):
    comparison = comparative_sentences.comparisons()[0]

# %%
nltk.download('comparative_sentences')

# %%
comparative_sentences.comparisons()[0]

# %%
comparative_sentences?

# %%
comparative_sentences?

# %%
data_1

# %%
data_1 = data_1.reset_index()
data_1= data_1.rename(columns = {'index': "reviewID"})
data_1 = data_1.drop(columns=['Unnamed: 0'])

# %%
data_1

# %%
data_1.to_csv('data_v1.csv', )

# %%
import pandas as pd

# %%
data_1 = pd.read_csv('data_v1.csv')

# %%
data_1

# %%
data_1.sent_text.value_counts()

# %%
data1 = data_1[['reviewID','asin', 'title','sent_text']]

# %%
data1

# %%
lis = [[0,1],[0,1],[2,2],[1,12]]
pd.DataFrame(data = lis)

# %%
temp= []
for idx in range(0,len(data1.sent_text)):
    for idx2 in data1.sent_text:
        print(idx2.split(','))
        break
    break
#         temp.append([idx, data1, ,idx2])

# %%
import re

# %%
re.split?

# %%
temp = []
for i,v in enumerate(data1.sent_text):
    try:
        for idx,g in enumerate(re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', v)):
            new_dict = {}
            new_dict['reviewID'] = i
            new_dict['title'] = data1.title[i]
            new_dict['asin'] = data1.asin[i]
            new_dict['sent_text']=g
            temp.append(new_dict)
        if (i%10000==0):
            print((i/len(data1)*100))
    except:
            new_dict = {}
            new_dict['reviewID'] = i
            new_dict['title'] = data1.title[i]
            new_dict['asin'] = data1.asin[i]
            new_dict['sent_text']=v
            temp.append(new_dict)

# %%
pd.DataFrame(temp)

# %%
temp
