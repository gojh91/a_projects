# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/ed/39/15045ae46f2a123019aa968dfcba0396c161c20f855f11dea6796bcaae95/PyMySQL-0.9.3-py2.py3-none-any.whl (47kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-0.9.3

# %%
import pymysql
import pandas as pd

db = pymysql.connect(
    host='ec2-13-209-223-88.ap-northeast-2.compute.amazonaws.com',  # DATABASE_HOST
    port=3306,
    user='nlpuser',  # DATABASE_USERNAME
    passwd='1234',  # DATABASE_PASSWORD
    db='nlp',  # DATABASE_NAME
    charset='utf8'
)

SQL = """SELECT asin, categories 
                FROM meta 
                WHERE categories LIKE '%camera%'"""
df = pd.read_sql(SQL, db)
df
# Out:
#              asin                                         categories
# 0      094339676X  [['Electronics', 'Camera & Photo', 'Accessorie...
# 1      0983947600  [['Electronics', 'Camera & Photo', 'Bags & Cas...
# 2      1948609819  [['Electronics', 'Camera & Photo', 'Accessorie...
# 3      3281220487  [['Electronics', 'Camera & Photo', 'Video Surv...
# 4      3902217138  [['Electronics', 'Camera & Photo', 'Film Photo...
# 5      4560170002  [['Electronics', 'Camera & Photo', 'Video Surv...
# 6      5135000011  [['Electronics', 'Camera & Photo', 'Accessorie...
# 7      5465426748  [['Electronics', 'Camera & Photo', 'Video Surv...
# 8      6000002556  [['Electronics', 'Camera & Photo', 'Accessorie...
# 9      6000005644  [['Electronics', 'Camera & Photo', 'Accessorie...
# 10     6000011474  [['Electronics', 'Camera & Photo', 'Accessorie...
# 11     6000005822  [['Electronics', 'Camera & Photo', 'Accessorie...
# 12     6000001134  [['Electronics', 'Camera & Photo', 'Accessorie...
# 13     6000012217  [['Electronics', 'Camera & Photo', 'Accessorie...
# 14     6000013248  [['Electronics', 'Camera & Photo', 'Accessorie...
# 15     6000007388  [['Electronics', 'Camera & Photo', 'Accessorie...
# 16     6000090188  [['Electronics', 'Camera & Photo', 'Accessorie...
# 17     6000006853  [['Electronics', 'Camera & Photo', 'Accessorie...
# 18     6000006926  [['Electronics', 'Camera & Photo', 'Accessorie...
# 19     6000006896  [['Electronics', 'Camera & Photo', 'Accessorie...
# 20     6010099161  [['Electronics', 'Camera & Photo', 'Accessorie...
# 21     6000008775  [['Electronics', 'Camera & Photo', 'Accessorie...
# 22     6000013159  [['Electronics', 'Camera & Photo', 'Accessorie...
# 23     6000007469  [['Electronics', 'Camera & Photo', 'Accessorie...
# 24     6000006179  [['Electronics', 'Camera & Photo', 'Accessorie...
# 25     6000089805  [['Electronics', 'Camera & Photo', 'Accessorie...
# 26     6010098858  [['Electronics', 'Camera & Photo', 'Accessorie...
# 27     6000007299  [['Electronics', 'Camera & Photo', 'Accessorie...
# 28     6000013094  [['Electronics', 'Camera & Photo', 'Accessorie...
# 29     6123015443  [['Electronics', 'Camera & Photo', 'Lighting &...
# ...           ...                                                ...
# 96319  B00L26IGP2  [['Electronics', 'Camera & Photo', 'Video Surv...
# 96320  B00L29CN7G  [['Electronics', 'Camera & Photo', 'Lighting &...
# 96321  B00L2GJBOW  [['Electronics', 'Camera & Photo', 'Video Surv...
# 96322  B00L34035E  [['Electronics', 'Camera & Photo', 'Tripods & ...
# 96323  B00L36HBNO  [['Electronics', 'Camera & Photo', 'Accessorie...
# 96324  B00L34051Q  [['Electronics', 'Camera & Photo', 'Tripods & ...
# 96325  B00L3OB2VS  [['Electronics', 'Camera & Photo', 'Bags & Cas...
# 96326  B00L4L31HI  [['Electronics', 'Camera & Photo', 'Accessorie...
# 96327  B00L4LT6EA  [['Electronics', 'Camera & Photo', 'Bags & Cas...
# 96328  B00L4YGZ1E  [['Electronics', 'Camera & Photo', 'Accessorie...
# 96329  B00L7O2AGA  [['Electronics', 'Camera & Photo', 'Accessorie...
# 96330  B00L7RNW2S  [['Electronics', 'Camera & Photo', 'Video', 'C...
# 96331  B00L8BN3MM  [['Electronics', 'Camera & Photo', 'Lenses', '...
# 96332  B00LAPAF1I  [['Electronics', 'Camera & Photo', 'Video Surv...
# 96333  B00LBETOCE                [['Electronics', 'Camera & Photo']]
# 96334  B00LBGMHF8  [['Electronics', 'Camera & Photo', 'Lenses', '...
# 96335  B00LBEUBBW  [['Electronics', 'Camera & Photo', 'Video Surv...
# 96336  B00LBWWQIA  [['Electronics', 'Camera & Photo', 'Digital Ca...
# 96337  B00LCAW7G2  [['Electronics', 'Camera & Photo', 'Lenses', '...
# 96338  B00LG0PERM  [['Electronics', 'Camera & Photo', 'Video Surv...
# 96339  B00LG6AMIM  [['Electronics', 'Camera & Photo', 'Accessorie...
# 96340  B00LG80VHM  [['Electronics', 'Camera & Photo', 'Binoculars...
# 96341  B00LFWLOCU  [['Electronics', 'Camera & Photo', 'Video Surv...
# 96342  B00LH4U5JO  [['Electronics', 'Security & Surveillance', 'A...
# 96343  B00LH52WT4  [['Electronics', 'Security & Surveillance', 'A...
# 96344  B00LHPXVBW  [['Electronics', 'Camera & Photo', 'Accessorie...
# 96345  B00LMCPYPG  [['Electronics', 'Camera & Photo', 'Accessorie...
# 96346  B00LMKAUU2  [['Electronics', 'Camera & Photo', 'Video', 'S...
# 96347  B00LPQRT34  [['Electronics', 'Camera & Photo', 'Digital Ca...
# 96348  B00LPQVF0M  [['Electronics', 'Camera & Photo', 'Digital Ca...
#
# [96349 rows x 2 columns]

# %%
SQL = """SELECT asin, categories 
                FROM meta 
                WHERE categories LIKE '%camera%'"""
df = pd.read_sql(SQL, db)
df

# %%
SQL = """SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_SCHEMA = 'nlp'"""
df = pd.read_sql(SQL, db)
df
# Out:
#     TABLE_NAME
# 0   Categories
# 1     Features
# 2     Products
# 3      Results
# 4   ReviewMeta
# 5      Reviews
# 6     Reviews2
# 7    Sentences
# 8        Teams
# 9     TotalDic
# 10        meta

# %%
SQL = """SELECT * FROM Sentences """
df = pd.read_sql(SQL, db)
df
# Out:
#         SentenceID CategoryID  TeamID  ReviewID BaseProductID RefProductID  \
# 0               11       None       6     95076          None         None
# 1               12       None       6     95076          None         None
# 2               13       None       6     95076          None         None
# 3               14       None       6     95076          None         None
# 4               15       None       6     95076          None         None
# 5               16       None       6     95076          None         None
# 6               17       None       6     95076          None         None
# 7               18       None       6     95076          None         None
# 8               19       None       6     95076          None         None
# 9               20       None       6     95076          None         None
# 10              21       None       6     95077          None         None
# 11              22       None       6     95077          None         None
# 12              23       None       6     95077          None         None
# 13              24       None       6     95077          None         None
# 14              25       None       6     95077          None         None
# 15              26       None       6     95077          None         None
# 16              27       None       6     95077          None         None
# 17              28       None       6     95079          None         None
# 18              29       None       6     95079          None         None
# 460954      None         None     None   None           None
# 460955      None         None     None   None           None
# 460956      None         None     None   None           None
# 460957      None         None     None   None           None
# 460958      None         None     None   None           None
#
#                                                  Sentence
# 0       I've had this camera for years now.... (5-7), ...
# 1       I would only recommend getting this camera bra...
# 2       It does not ruin the camera itself (I called h...
# 3       If you do leave the battery over a long period...
# 4       This was my fault as I attached it too tightly...
# 5       It has a variety of features including action ...
# 6       It's done for you automatically, and you can c...
# 7       The only thing I really see wrong with it is t...
# 8       If you need parts (like rechargeable batteries...
# 9       And overall, I would only recommend getting ne...
# 10      ... after two previous attempts at buying my m...
# 11                                                  YEAH!
# 12      She's 68 and has a bit of difficulty with dext...
# 13      HP also provides a docking station now that I ...
# 14      It's very easy to learn and very light weight ...
# 15               The picture quality is great at a +5 MP!
# 16                       For this price - can't go wrong.
# 17      I got the HP R707 shortly after it was introdu...
# 18      The first thing I noticed about the camera was...
# 19      They were clear and crisp and the colors were ...
# 20      The second thing I noticed was how long the  i...
# 21      It was more than a month before I had to charg...
# 22      I bought a second battery of course, but that ...
# 23      It is a bit chunky compared to the models out ...
# 24      No buttons or menus to fuss with, just set it ...
# 25      If you like to fine tune there are plenty of f...
# 26      In camera red eye reduction is avialable, as i...
# 27      You can also force the flash to fire when the ...
# 28      In addition there is a "my settings" menu opti...
# 29      It also has something missing in most of today...
# ...                                                   ...
# 460929  ]google casio exilim ex-z77 10 min file size a...
# 460930  The picture quality and sound are GREAT but th...
# 460931  with very small improvements to my two problem...
# 460932  On my hedgehog video you can hear the clicking...
# 460933         It also has  a better on board microphone.
# 460934                                   Hope this helps!
# 460935  My daughter loves this camera -- we gave it to...
# 460936  It's small with a large viewing area and easy ...
# 460937                Great pictures too -- she loved it.
# 460938  I have had this camera a little more than a we...
# 460939  I bought it to replace an Olympus D-435 that w...
# 460940  The old camera had a few flaws that I was care...
# 460941  Most importantly, I needed much less shutter lag.
# 460942  The Exilim takes a picture immediately when yo...
# 460943  It also has a much bigger display screen so yo...
# 460944  The menu system is easy to get the hang of and...
# 460945  I bought mine in combination with a 2GB memory...
# 460946  I can now take up to 461 pictures with everyth...
# 460947  I even took pictures while riding in a bouncy ...
# 460948        And it definitely comes at the right price.
# 460949        My son asked for this camera for Christmas.
# 460950                      So far we are very impressed.
# 460951  It takes very nice pictures and the video is e...
# 460952  Very impressed with how long it records and ho...
# 460953  I had the same camera but it got stollen, so I...
# 460954        Very stable images (anti-shake works well!)
# 460955  and I particularly like the fact that the pict...
# 460956  I had an EX-Z77 camera for two years.I loved t...
# 460957  )I never had problems with it and took some am...
# 460958  I lost it and I want to buy the same model aga...
#
# [460959 rows x 12 columns]

# %%
SQL = """SELECT * FROM Reviews """
df = pd.read_sql(SQL, db)
df
# Out:
#          ReviewID  CategoryID ProductID        ASIN  Score  ReviewDate Title  \
# 0              16           1      None  0132793040    5.0  2013-04-13
# 1              17           1      None  0321732944    5.0  2012-07-01
# 2              18           1      None  0439886341    1.0  2013-04-29
# 3              19           1      None  0439886341    3.0  2013-07-22
# 4              20           1      None  0439886341    1.0  2012-04-18
# 5              21           1      None  0511189877    5.0  2014-04-14
# 6              22           1      None  0511189877    2.0  2014-04-14
# 7              23           1      None  0511189877    5.0  2014-03-27
#                                                     Review Style HelpfulScore  \
# 0        Corey Barker does a great job of explaining Bl...             [1, 1]
# 1        While many beginner DVDs try to teach you ever...             [0, 0]
# 2        It never worked. My daughter worked to earn th...             [1, 1]
# 3        Some of the functions did not work properly.  ...             [1, 1]
# 4        Do not waste your money on this thing it is te...             [4, 4]
# 5        Dog got the old remote and destroyed it.  Didn...             [0, 0]
# 6        This remote, for whatever reason, was chosen b...             [1, 1]
# 7        We had an old Time Warner Cable remote that wa...             [0, 1]
# 8        This unit works just like the TEC unit only be...             [0, 0]
# 9        It is an exact duplicate of my Time warner rem...             [0, 0]
# 10       Works on my t.v. that no other remote works on...             [0, 1]
# 11       Corey Barker does a great job of explaining Bl...             [1, 1]
# 12       While many beginner DVDs try to teach you ever...             [0, 0]
# 13       It never worked. My daughter worked to earn th...             [1, 1]
# 14       Some of the functions did not work properly.  ...             [1, 1]
# 15       Do not waste your money on this thing it is te...             [4, 4]
# 16       Dog got the old remote and destroyed it.  Didn...             [0, 0]
# 17       This remote, for whatever reason, was chosen b...             [1, 1]
# 18       We had an old Time Warner Cable remote that wa...             [0, 1]
# 19       This unit works just like the TEC unit only be...             [0, 0]
# 20       It is an exact duplicate of my Time warner rem...             [0, 0]
# 21       Works on my t.v. that no other remote works on...             [0, 1]
# 22       Love it has everything I wanted any problems w...             [0, 0]
# 23       I have owned two Rand McNally GPS devices over...             [0, 0]
# 24       We got this GPS for my husband who is an (OTR)...             [0, 0]
# 25       I'm a professional OTR truck driver, and I bou...           [12, 15]
# 26       This is a great truck GPS. I've tried others a...           [21, 22]
# 27       Well, what can I say.  I've had this unit in m...           [43, 45]
# 28       Not going to write a long review, even thought...            [9, 10]
# 29       My brother is a trucker and pre-ordered this. ...           [23, 32]
# ...                                                    ...   ...          ...
# 7824463  We are longtime Power LogOn users in our corpo...             [1, 1]
# 7824464  We have used this product for over 6 years now...             [1, 1]
# 7824465  I am an Ophthalmologist and have used electron...             [1, 1]
# 7824466  I'm an IT pro and have Installed it on my clie...             [2, 2]
# 7824467  nimblstand is great! It is part of my desk sit...             [0, 0]
# 7824468  I received my KTU10 today. I ordered it becaus...             [2, 2]
# 7824469  I bought this adapter directly from the Kanex ...             [2, 2]
# 7824470  The Samsung NX Mini feels very solid, yet very...             [4, 6]
# 7824471  I love the cute backpack. It is for my college...             [0, 0]
# 7824472  Although I do not own one but a friend of mine...             [0, 0]
# 7824473  This ECOCRAFTWORLD bag is great for travelling...             [1, 1]
# 7824474  The cable has allowed me to keep my HD video c...             [0, 0]
# 7824475  The item is very old, the machine that needed ...             [0, 8]
# 7824476  I had a problem downloading my tracks on my Ga...             [0, 0]
# 7824477  I am still using this product (or at least par...             [0, 0]
# 7824478  I think the sturdiness and quality of this pro...             [9, 9]
# 7824479  Sturdy and well made.  Gave me extra space on ...             [0, 0]
# 7824480  Received this drawer well packaged and very qu...           [10, 10]
# 7824481  I ordered this keyboard based on the size of t...             [0, 0]
# 7824482  I have an old oak desk that my father rescued ...             [0, 0]
# 7824483  It works perfectly with our sound desk at chur...             [0, 0]
# 7824484  Very cheap looking, my customer was not happy ...             [0, 0]
# 7824485  This installed easily and is quite stable.  Th...             [0, 0]
# 7824486  I'll keep this brief.Like:Keyboard tray has a ...             [2, 2]
# 7824487  MY keyboard is just what I needed and with my ...             [0, 0]
# 7824488  The included template made it easy to install....             [0, 0]
# 7824489  The item came sooner than expected and was in ...             [2, 4]
# 7824490  It's a great little device, especially when yo...             [0, 0]
# 7824491  I have a small desk and this fits perfectly.  ...             [5, 5]
# 7824492  There is nothing wrong with the mount, you're ...             [0, 0]
#
#         ValidPurchase UserIP LastUpdatedDate      ReviewerID  \
# 0                       None            None   AKM1MP6P0OYPR
# 1                       None            None  A2CX7LUOHB2NDG
# 2                       None            None  A2NWSAGRHCP8N5
# 3                       None            None  A2WNBOD3WNDNKT
# 4                       None            None  A1GI0U4ZRJA8WN
# 5                       None            None  A1QGNMC6O1VW39
# 6                       None            None  A3J3BRHTDRFJ2G
# 7                       None            None  A2TY0BTJOTENPG
# 8                       None            None  A34ATBPOK6HCHY
# 9                       None            None   A89DO69P0XZ27
# 10                      None            None   AZYNQZ94U6VDB
# 11                      None            None   AKM1MP6P0OYPR
# 12                      None            None  A2CX7LUOHB2NDG
# 13                      None            None  A2NWSAGRHCP8N5
# 14                      None            None  A2WNBOD3WNDNKT
# 15                      None            None  A1GI0U4ZRJA8WN
# 16                      None            None  A1QGNMC6O1VW39
# 17                      None            None  A3J3BRHTDRFJ2G
# 18                      None            None  A2TY0BTJOTENPG
# 19                      None            None  A34ATBPOK6HCHY
# 20                      None            None   A89DO69P0XZ27
# 21                      None            None   AZYNQZ94U6VDB
# 22                      None            None  A1DA3W4GTFXP6O
# 23                      None            None  A29LPQQDG7LD5J
# 24                      None            None   AO94DHGC771SJ
# 25                      None            None   AMO214LNFCEI4
# 26                      None            None  A28B1G1MSJ6OO1
# 27                      None            None  A3N7T0DY83Y4IG
# 28                      None            None  A1H8PY3QHMQQA0
# 29                      None            None   A2CPBQ5W4OGBX
# ...               ...    ...             ...             ...
# 7824463                 None            None  A3AENU8Y9HLRAQ
# 7824464                 None            None   ABX8TXRB2GSKO
# 7824465                 None            None  A1QUWXCBPGCQMW
# 7824466                 None            None  A37B1XSZUYNSNK
# 7824467                 None            None  A3FOXB6244Y5PC
# 7824468                 None            None   AELQMX8YAEEYI
# 7824469                 None            None   AG1NNE1V43RWC
# 7824470                 None            None  A2QW4HHHC6XWH4
# 7824471                 None            None  A2025SOZT6OE6D
# 7824472                 None            None  A2DOJYSPCLCQIT
# 7824473                 None            None  A1PB6OT0OOPKNQ
# 7824474                 None            None  A1MTPZKAYVSES3
# 7824475                 None            None   AS7WVL4JGN1FI
# 7824476                 None            None  A3GGII8ILEUI4P
# 7824477                 None            None   ATK4Q037EM13F
# 7824478                 None            None   AT10LK8R9MLHT
# 7824479                 None            None   AKVMJCP7T93X1
# 7824480                 None            None  A2H4BLBXDNSZ2O
# 7824481                 None            None  A2DARIL2TWUOLS
# 7824482                 None            None   A7ETK9SC1HAMP
# 7824483                 None            None   A5FUA9HEV2O42
# 7824484                 None            None   A84WRQR47OOKR
# 7824485                 None            None  A180UGKKYCPDH0
# 7824486                 None            None  A2R6Q6KJCYSVH7
# 7824487                 None            None  A2IGIIABRZ5LAB
# 7824488                 None            None  A2YZI3C9MOHC0L
# 7824489                 None            None  A322MDK0M89RHN
# 7824490                 None            None  A1MH90R0ADMIK0
# 7824491                 None            None  A10M2KEFPEQDHN
# 7824492                 None            None  A2G81TMIOIDEQQ
#
#                  ReviewerName                           Summary
# 0        Vicki Gibson "momo4"                     Very thorough
# 1                      Bernie  Adobe Photoshop CS5 Crash Course
# 2                 bowmans2007               absolutely horrible
# 3                         JAL                     Disappointing
# 4                   Truthfull    TERRIBLE DONT WASTE YOUR MONEY
# 5                          CK       Works Great with my TWC box
# 6          EJ Honda "ejhonda"               Ergonomic nightmare
# 7                  Johnny Exx  Excellent replacement to Time Wa
# 8            Nancy C. Johnson                       Great piece
# 9             Stephen Schultz          Time Warner cable remote
# 10           Terri L. Pittman                           Awesome
# 11                                                Very thorough
# 12                             Adobe Photoshop CS5 Crash Course
# 13                                          absolutely horrible
# 14                                                Disappointing
# 15                               TERRIBLE DONT WASTE YOUR MONEY
# 16                                  Works Great with my TWC box
# 17                                          Ergonomic nightmare
# 18                             Excellent replacement to Time Wa
# 19                                                  Great piece
# 20                                     Time Warner cable remote
# 21                                                      Awesome
# 22                                                      love it
# 23                                                Piece of Junk
# 24                                              Gotta have GPS!
# 25                                            Very Disappointed
# 26                                                  Great Unit!
# 27                                               1st impression
# 28                                      Great grafics, POOR GPS
# 29                             New GPS doesn't work with new Wi
# ...                       ...                               ...
# 7824463                        We are longtime Power LogOn user
# 7824464                                             A Must Have
# 7824465                        This great product has allowed m
# 7824466                        Excellent product works flawless
# 7824467                        'Why didn't somebody think of th
# 7824468                        Major Asset for Macs with Thunde
# 7824469                        Does not work with OS 10.9 Maver
# 7824470                        A Solid Option for Hobbyist & Am
# 7824471                                     exactly what I need
# 7824472                                             Awesome !!!
# 7824473                                              Five Stars
# 7824474                                           Get organized
# 7824475                                               Out dated
# 7824476                                       Excellent product
# 7824477                                            okay product
# 7824478                                      Fine for the money
# 7824479                                                 Love it
# 7824480                        Excellent product - Excellent pr
# 7824481                                        Check Dimensions
# 7824482                         made my vintage desk ergonomic!
# 7824483                        the slide out mouse pad is aweso
# 7824484                               Underdesk keyboard drawer
# 7824485                                     Just what I needed.
# 7824486                        Nice design but mousepad is too
# 7824487                             Underdesk or Table Keyboard
# 7824488                                               Well Made
# 7824489                                         Keyboard Drawer
# 7824490                                 Great buy for the price
# 7824491                                   good for a small desk
# 7824492                        Best mount built ever, for Gamin
#
# [7824493 rows x 16 columns]

# %% [markdown]
# ### 데이터 저장

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  passwd="yourpassword",
  database="mydatabase"
)

mycursor = mydb.cursor()

sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("Michelle", "Blue Village")
mycursor.execute(sql, val)

mydb.commit()

print("1 record inserted, ID:", mycursor.lastrowid)

# %% [markdown]
# ### 데이터 수정

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  passwd="yourpassword",
  database="mydatabase"
)

mycursor = mydb.cursor()

sql = "UPDATE customers SET address = 'Canyon 123' WHERE address = 'Valley 345'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")

# %% [markdown]
# ### 데이터 삭제

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  passwd="yourpassword",
  database="mydatabase"
)

mycursor = mydb.cursor()

sql = "DELETE FROM customers WHERE address = 'Mountain 21'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
