# %%
import pandas as pd
from sqlalchemy import create_engine

file = 'MPQA_total_DIC'

# %%
df = pd.read_csv(file+'.csv')

engine = create_engine("mysql+pymysql://nlpuser:"+"1234"+"@ec2-13-209-223-88.ap-northeast-2.compute.amazonaws.com/nlp?charset=utf8", encoding='utf-8')

conn = engine.connect()
df.to_sql(name=file, con=engine, if_exists='append', index=False)
conn.close()

# %%
# !pip install nltk

# %%
import nltk
from nltk.corpus import comparative_sentences
nltk.download('comparative_sentences')
a = comparative_sentences.keywords_readme()
# Out:
# [nltk_data] Downloading package comparative_sentences to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package comparative_sentences is already up-to-date!

# %%
df = pd.DataFrame()
df['kw']=a[5:]

# %%
df
# Out:
#              kw
# 0          beat
# 1      inferior
# 2      outstrip
# 3          both
# 4   on par with
# 5        Choice
# 6        choose
# 7        prefer
# 8     recommend
# 9    outperform
# 10     superior
# 11          all
# 12   up against
# 13         less
# 14        favor
# 15       defeat
# 16        twice
# 17       thrice
# 18         half
# 19         same
# 20       either
# 21      Compete
# 22   Number one
# 23   one of few
# 24         more
# 25         like
# 26       behind
# 27      similar
# 28    identical
# 29       Versus
# ..          ...
# 48        ahead
# 49     fraction
# 50        outdo
# 51        match
# 52    unmatched
# 53     peerless
# 54       differ
# 55   One of few
# 56       outwit
# 57        rival
# 58    alternate
# 59      Compare
# 60          top
# 61       exceed
# 62         lead
# 63          win
# 64     outstrip
# 65         none
# 66         near
# 67    unrivaled
# 68     dominate
# 69       second
# 70    nonpareil
# ...

# %%
engine = create_engine("mysql+pymysql://nlpuser:"+"1234"+"@ec2-13-209-223-88.ap-northeast-2.compute.amazonaws.com/nlp?charset=utf8", encoding='utf-8')

conn = engine.connect()
df.to_sql(name='kw', con=engine, if_exists='append', index=False)
conn.close()
