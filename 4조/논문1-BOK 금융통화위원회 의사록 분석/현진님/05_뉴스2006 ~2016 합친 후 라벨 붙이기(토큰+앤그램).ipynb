# %% [markdown]
# # 뉴스 2006~2016 자료 합치기

# %%
import pandas as pd
df2005 = pd.read_csv("04news2005_sum.csv",encoding = 'utf-8')
df2006 = pd.read_csv("04news2006_sum.csv",encoding = 'utf-8')
df2007 = pd.read_csv("04news2007_sum.csv",encoding = 'utf-8')
df2008 = pd.read_csv("04news2008_sum.csv",encoding = 'utf-8')
df2009 = pd.read_csv("04news2009_sum.csv",encoding = 'utf-8')
df2010 = pd.read_csv("04news2010_sum.csv",encoding = 'utf-8')
df2011 = pd.read_csv("04news2011_sum.csv",encoding = 'utf-8')
df2012 = pd.read_csv("04news2012_sum.csv",encoding = 'utf-8')
df2013 = pd.read_csv("04news2013_sum.csv",encoding = 'utf-8')
df2014 = pd.read_csv("04news2014_sum.csv",encoding = 'utf-8')
df2015 = pd.read_csv("04news2015_sum.csv",encoding = 'utf-8')
df2016 = pd.read_csv("04news2016_sum.csv",encoding = 'utf-8')
df2005.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2006.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2007.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2008.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2009.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2010.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2011.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2012.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2013.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2014.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2015.drop(['Unnamed: 0'], axis='columns', inplace = True)
df2016.drop(['Unnamed: 0'], axis='columns', inplace = True)

# %% [markdown]
# # dataframe 아래로 이어 붙이기

# %%
df = pd.concat([df2005,df2006,df2007,df2008,df2009,df2010,df2011,df2012,df2013,df2014,df2015,df2016])
# Out:
# C:\Users\khjin\.conda\envs\jin\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.drop(['Unnamed: 0.1'],axis='columns',inplace=True)
df.head()
# Out:
#          date   media                                               news  \
# 0  2005.01.01  연합인포맥스  2005년 10년만기 미국 국채수익률이  연방준비제도이사회(FRB)의 금리인상 지속...
# 1  2005.01.01  연합인포맥스  2년만기 국채가격 4년래 최악의 한해 보내     10년만기 미국  국채수익률이  ...
# 2  2005.01.01    연합뉴스  전남 강진군이 농가 소득보전 차원의   이차(利差)보전 사업을 대폭 확대한다.   ...
# 3  2005.01.01    연합뉴스                                                 ))
# 4  2005.01.01  연합인포맥스  2004년 마지막 거래일인 31일  뉴욕환시에서 미국 달러화는 개장초 102엔 근처...
#
#                                   title  \
# 0               내년 美국채수익률 5% 넘어서기 어려울 듯
# 1  [뉴욕채권-마감] 10년만기 국채수익률 작년보다 낮은 수준서 마쳐
# 2                     강진군 이차보전 사업 대폭 확대
# 3        <표> 은행 금전신탁배당률.정기예금 금리(12.31일)
# 4       [뉴욕환시] `내년초 달러-엔에 주력'..달러 對엔 하락
#
#                                         tokens_ngram  \
# 0  만기/NNG,국채/NNG,수익률/NNG,fed/NNG,fed/NNG,금리/NNG,인...
# 1  만기/NNG,국채/NNG,가격/NNG,최악/NNG,보내/VV,만기/NNG,국채/NN...
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df = df[['date','media','url','title','news','tokens_ngram']]

# %%
df.head()
# Out:
#          date   media                                                url  \
# 0  2005.01.01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  2005.01.01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  2005.01.01    연합뉴스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  2005.01.01    연합뉴스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  2005.01.01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                   title  \
# 0               내년 美국채수익률 5% 넘어서기 어려울 듯
# 1  [뉴욕채권-마감] 10년만기 국채수익률 작년보다 낮은 수준서 마쳐
# 2                     강진군 이차보전 사업 대폭 확대
# 3        <표> 은행 금전신탁배당률.정기예금 금리(12.31일)
# 4       [뉴욕환시] `내년초 달러-엔에 주력'..달러 對엔 하락
#
#                                                 news  \
# 0  2005년 10년만기 미국 국채수익률이  연방준비제도이사회(FRB)의 금리인상 지속...
# 1  2년만기 국채가격 4년래 최악의 한해 보내     10년만기 미국  국채수익률이  ...
# 2  전남 강진군이 농가 소득보전 차원의   이차(利差)보전 사업을 대폭 확대한다.   ...
# 3                                                 ))
# ...

# %%
df_2 = df.copy()

# %%
len(df_2)
# Out:
# 278220

# %%
df_2 = df_2.dropna(axis=0)

# %%
len(df_2)
# Out:
# 252986

# %%
278220-252986
# Out:
# 25234

# %%
df_2
# Out:
#              date   media                                                url  \
# 0      2005.01.01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1      2005.01.01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4      2005.01.01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 5      2005.01.01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 6      2005.01.01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 7      2005.01.01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 8      2005.01.01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 9      2005.01.01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 10     2005.01.02    연합뉴스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 11     2005.01.02    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 13     2005.01.02    연합뉴스  https://news.naver.com/main/read.nhn?mode=LSD&...
# ...

# %%
call_rate
# Out:
#             date    old_date  callrate  old_callrate      updown
# 3605  2005-01-03  2004-12-04      3.27          3.26          up
# 3604  2005-01-04  2004-12-05      3.27          3.26          up
# 3603  2005-01-05  2004-12-06      3.28          3.23          up
# 3602  2005-01-06  2004-12-07      3.21          3.19          up
# 3601  2005-01-07  2004-12-08      3.22          3.27        down
# 3600  2005-01-10  2004-12-11      3.27          3.28        down
# 3599  2005-01-11  2004-12-12      3.28          3.19          up
# 3598  2005-01-12  2004-12-13      3.27          3.28        down
# 3597  2005-01-13  2004-12-14      3.28          3.28  neutrality
# 3596  2005-01-14  2004-12-15      3.26          3.28        down
# 3595  2005-01-17  2004-12-18      3.25          3.28        down
# 3594  2005-01-18  2004-12-19      3.25          3.28        down
# 3593  2005-01-19  2004-12-20      3.25          3.29        down
# ...

# %%
call_rate = pd.read_csv("callrate_final.csv",encoding = 'utf-8')

# %%
call_rate = call_rate.sort_values(by = 'date')

# %%
call_rate = call_rate.reset_index()

# %%
del call_rate['old_date']
del call_rate['callrate']
del call_rate['old_callrate']

# %%
del call_rate['index']

# %%
call_rate['date'] = pd.to_datetime(call_rate['date'])

# %%
df_2['date'] = pd.to_datetime(df_2['date'])

# %%
import pandas as pd 
A = pd.merge(df_2,call_rate,on='date',how='left')
A
# Out:
#              date   media                                                url  \
# 0      2005-01-01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1      2005-01-01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2      2005-01-01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3      2005-01-01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4      2005-01-01  연합인포맥스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 5      2005-01-01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 6      2005-01-01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 7      2005-01-01    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 8      2005-01-02    연합뉴스  https://news.naver.com/main/read.nhn?mode=LSD&...
# 9      2005-01-02    이데일리  https://news.naver.com/main/read.nhn?mode=LSD&...
# 10     2005-01-02    연합뉴스  https://news.naver.com/main/read.nhn?mode=LSD&...
# ...

# %% [markdown]
# # 값이 없는 경우 앞에 뒤에 값으로 채워주기

# %%
A = A.fillna(method = 'ffill')
if A.isnull().values.any():
    A = A.fillna(method = 'bfill')

# %%
A[['date','updown']]
# Out:
#              date updown
# 0      2005-01-01     up
# 1      2005-01-01     up
# 2      2005-01-01     up
# 3      2005-01-01     up
# 4      2005-01-01     up
# 5      2005-01-01     up
# 6      2005-01-01     up
# 7      2005-01-01     up
# 8      2005-01-02     up
# 9      2005-01-02     up
# 10     2005-01-02     up
# 11     2005-01-02     up
# 12     2005-01-02     up
# 13     2005-01-02     up
# 14     2005-01-02     up
# 15     2005-01-02     up
# 16     2005-01-03     up
# 17     2005-01-03     up
# 18     2005-01-03     up
# 19     2005-01-03     up
# 20     2005-01-03     up
# 21     2005-01-03     up
# 22     2005-01-03     up
# 23     2005-01-03     up
# 24     2005-01-03     up
# 25     2005-01-03     up
# 26     2005-01-03     up
# 27     2005-01-03     up
# 28     2005-01-03     up
# 29     2005-01-03     up
# ...           ...    ...
# 252956 2016-12-30     up
# 252957 2016-12-30     up
# 252958 2016-12-30     up
# 252959 2016-12-30     up
# 252960 2016-12-30     up
# ...

# %%
A.to_csv("05_news_total_label.csv",encoding = 'utf-8')

# %%
import pandas as pd
A = pd.read_csv("05_news_total_label.csv",encoding = 'utf-8')

# %%
len(A)
# Out:
# 252986

# %%
del A['tokens_ngram']
del A['updown']

# %%
A.to_csv('news_file.csv',encoding='utf-8')
