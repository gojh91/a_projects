# %%
import requests
from bs4 import BeautifulSoup

# %%
http://search.danawa.com/dsearch.php?query=%EC%82%BC%EC%84%B1%EC%B9%B4%EB%A9%94%EB%9D%BC
    &originalQuery=%EC%82%BC%EC%84%B1%EC%B9%B4%EB%A9%94%EB%9D%BC
    &previousKeyword=%EC%82%BC%EC%84%B1%EC%B9%B4%EB%A9%94%EB%9D%BC
    &cate_c1=842
    &cate_c2=843
    &page=1
    &limit=90

# %%
base_url = 'http://search.danawa.com/dsearch.php?query=%EC%82%BC%EC%84%B1%EC%B9%B4%EB%A9%94%EB%9D%BC&originalQuery=%EC%82%BC%EC%84%B1%EC%B9%B4%EB%A9%94%EB%9D%BC&previousKeyword=%EC%82%BC%EC%84%B1%EC%B9%B4%EB%A9%94%EB%9D%BC&cate_c1=842&cate_c2=843&limit=90&page='
headers = {
    'User_Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'
 }



for i in range(1,8):
    resp = requests.get(base_url+str(i), headers = headers)
    soup = BeautifulSoup(resp.content, 'html.parser')
    
    table = soup.find('div', id='productListArea')
#     .find('div', class_='main_prodlist.main_prodlist_list')
    print(soup)
    break
# Out:
# <html><header><title>Error</title></header><body><h2>Error</h2><table bgcolor="#FEEE7A" border="0" cellpadding="0" cellspacing="0" width="400"><tr><td><table border="0" cellpadding="3" cellspacing="1"><tr align="Left" bgcolor="#FBFFDF" valign="top"><td><strong>Error</strong></td></tr><tr bgcolor="#FFFFFF" valign="top"><td>This page can't be displayed. Contact support for additional information.<br/>The incident ID is: 6662400051074380654.</td></tr></table></td></tr></table></body></html>

# %%
samsung_list = [
    'NX mini',
    'NX3000',
    'NX1'.
    'NX300M',
    'NX500',
    'NX1000',
    'NX300',
    'NX30',
    'VLUU EX2F',
    'NX2000',
    'VLUU EK-GC200',
    'NX20',
    'NX100',
    'NX10',
    'GX-20',
    'MV900F',
    'VLUU DV180F',
    'VLUU DV150F',
    'ST66',
    'WB150F',
    'DV300F',
    'WB2100',
    'WB50F',
    'WB850F',
    'VLUU PL100',
    'MV800',
    'VLUU PL150'
    'VLUU ST550',
    'VLUU EX1',
    'WB35F',
    'NX200',
    'VLUU PL60',
    'WB350F',
    'VLUU ST65',
    'VLUU ST500',
    'WB250F',
    'GX-10',
    'VLUU ST88',
    'WB750',
    'VLUU PL120',
    'WB100',
    'VLUU ST710',
    'VLUU ST50',
    'WB1000',
    'VLUU ST90',
    'VLUU ST60',
    'ST72',
    'VLUU ST600',
    'VLUU DV2014F',
    'WB380F',
    'ES95',
    'VLUU ES55',
    'VLUU ES65',
    'VLUU WB1100F',
    'NX11',
    '갤럭시 NX',
    'VLUU PL200',
    'WB500',
    'VLUU ES25',
    'VLUU EK-GC110',
    'VLUU WB5500',
    'SH100',
    'VLUU ES75',
    'NX5',
    'VLUU ES20',
    'VLUU ST95',
    'WB5000',
    'ST77',
    'VLUU L100',
    'NX210',
    'VLUU NV9',
    'VLUU PL121',
    'VLUU ST1000',
    'VLUU ST10',
    'WB210',
    'ES80',
    'VLUU PL101',
    'VLUU ST30',
    'VLUU NV20',
    'VLUU L301',
    'KENOX D860',
    'VLUU i70',
    'VLUU L2',
    'VLUU PL50',
    'VLUU M300W',
    'VLUU EK-GC110',
    'VLUU i85',
    'VLUU ST5500',
    'WB600',
    'VLUU ST5000'
    
    'VLUU ST80',
    'VLUU PL20',
    'VLUU ES71',
    'VLUU ST6500',
    
    
    
    
    
    
    
]

# %%
a = 
ST80
PL20
ES71
ST6500
WP10
PL171
ST150F
ST200F
DV100
PL80
ST71
ST100
ES30
WB2000
ST96
ES70
ES90
ES28
WB30F
ST700
WB800F
PL210
NV15
WB550
PL51
ES17
PL70
NV11
NV10
WB200F
ES15
WB700
PL170
NV100HD
i80
ES73
ST70
ES60
NV24HD
ST45
i8
PL10
PL55
S1070
ES10
PL65
IT100
NV30
L83T
L73 
SDC-K65S
S800
SL50
DV100
ES80
ST77
ST76
ST150F
EK-GC110 
M110
NV404
NV4
TL210
TL240
SL50
TL205
CL80
SL600
i100
L201
L201
S16
L310W
M100
L200
NV40
L1
S1060
L110
L210
D760
D70
V7
S860
S760
S85
NV8
S730 
S730

# %%
D70
L730
L830
L83T
L730
L830
L77
i70
GX-1L
NV3 
NV5
SDC-K65S
S1030
S830
KENOX S700
L74 
i7
SDC-K60R
SDC-K50
X700
L73 실
S1050 
S850 
S730 
S630 
i70 
S630 
S730 
S850 
S1050 
SDC-K65B
X80
X70
S1000
S70
NV7 OPS
NV3
X60
11 PMP
V700
GX-1S
D-XENON 18-55
D-XENON 50-200
SDC-K50
V10 
X85
35 MP3
S600
S800
S500
11 PMP
i5
SDC-K50
D610
V20
Digimax 202
ME-5
Digimax 200
KENOX U-CA3 
D6_KENOX
Digimax 340
SDC-210
V4000_KENOX
D4_KENOX
U-CA3 
410
Digimax 101
KENOX X15 WIDE
V6
V10 
KENOX U-CA5
Q2
D250
Cyber410
Cyber300_KENOX
α7_KENOX
D502_KENOX

# %%
D401_KENOX
D3100_KENOX
D50_KENOX
V4_KENOX
D470_KENOX
D370_KENOX
Digimax 300
Digimax 130
Digimax 301
KENOX U-CA50
Digimax 330
D430_KENOX
Digimax 230
V3
Digimax 240
Digimax 35
Pro815
X1
V5
KENOX V10 
KENOX UX4
KENOX U-CA4
KENOX U-CA3
Q25WIDE
Q1
Cyber400_KENOX
CD4_KENOX
α5_KENOX
D4000_KENOX
D7_KENOX
D5_KENOX
MP3_KENOX
D530_KENOX
Digimax 420
Digimax 350
Digimax 201
MV800
EX1
EX2F
WB850F
V2500
NX300M
NX1
EX2F
V2000
ZL-4
ST90
ST500
NX30
WB700
WB35F
WB200F
NX200
ES65
ES10
NX30
ES20
PL170
PL121
EX2F
L100
ST70
NX30
WB250F
ST50
ST5500
NX300M
SH100
NXmini
NX210 
WB35F

# %%
NX30
WB250F
ST50
ST5500
NX200
ES65
ES10
NX30
ES20 
PL170
PL121
EX2F
ST5000
NX300M 
SH100
ST201
EC-ST700ST600
ST50
NX10
ST66
NX300
WB35F
ST60
PL100
WB35F
NX200
WB30F
PL60 
WB700
WB35F
WB200F
EK-GC200
WB35F
DV150F
ES30
ST150F
 NX11 
WB850F
PL120
NX3000
ST201
ES17 
ST50 
ST201
ST50
ST1000
ST710 
WB750 
WB850F
WB35F
PL150
PL70
WB850F 
NX210 
PL200 
WB1000 
DV180F
WB50F 
PL51
ST72 
NX210
WB35F
MV900F
WB35F
ES95 
WB500
ST700
NX2000

# %%
ES80
m70
NX11
V2000
ST700
ES95
ST600
ST20
ST201
i7
KENOX S800
SHW-M250L
V1500 
SHV-E500S
SM-J510L
WB2100
SHW-M200
WB5000
VM-A670
SHV-E210L
ST201
V2500
NX20 
ST201
NX20
NV3
VM-A350T
i70
SHV-E310L
KENOX D430
NV8
KENOX D4
NV3
SHV-E310L
EK-GC100ZWAKOO
V1500
WB850F 
N3000
GX10
SF-A
NX200
ES70
ST201
NX300
NX3000
ST95
NX11
MV800
SDC-80
NX100 
SDC-35
WB200F

# %%
ST201
WB500
M110
ST201
WB200F
SDC-4304
DYLAX-7XI
NX300M

# %%
test = 'i like ST5500'

'ST5500' in test
# Out:
# True

# %%
ST5500
NX300M
