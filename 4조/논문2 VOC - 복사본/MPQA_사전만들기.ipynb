# %%
import pandas as pd

# %% [markdown]
# ## 긍정

# %%
a = pd.read_csv('positive-words.txt',encoding= 'utf-8', names=['POS_word'])

# %%
a
# Out:
#              POS_word
# 0                  a+
# 1              abound
# 2             abounds
# 3           abundance
# 4            abundant
# 5          accessable
# 6          accessible
# 7             acclaim
# 8           acclaimed
# 9         acclamation
# 10           accolade
# 11          accolades
# 12      accommodative
# 13       accomodative
# 14         accomplish
# 15       accomplished
# 16     accomplishment
# 17    accomplishments
# 18           accurate
# 19         accurately
# 20         achievable
# 21        achievement
# 22       achievements
# 23         achievible
# 24             acumen
# 25          adaptable
# 26           adaptive
# 27           adequate
# 28         adjustable
# 29          admirable
# ...               ...
# 1976            witty
# 1977              won
# 1978           wonder
# 1979        wonderful
# 1980      wonderfully
# 1981        wonderous
# 1982      wonderously
# 1983          wonders
# 1984         wondrous
# ...

# %%
a.to_csv('MPQA_POS_DIC.csv', encoding='utf-8')

# %% [markdown]
# ## 부정

# %%
b = pd.read_csv('negative-words.txt',encoding= 'utf-8', names=['NEG_word'])

# %%
b
# Out:
#            NEG_word
# 0           2-faced
# 1           2-faces
# 2          abnormal
# 3           abolish
# 4        abominable
# 5        abominably
# 6         abominate
# 7       abomination
# 8             abort
# 9           aborted
# 10           aborts
# 11           abrade
# 12         abrasive
# 13           abrupt
# 14         abruptly
# 15          abscond
# 16          absence
# 17    absent-minded
# 18         absentee
# 19           absurd
# 20        absurdity
# 21         absurdly
# 22       absurdness
# 23            abuse
# 24           abused
# 25           abuses
# 26          abusive
# 27          abysmal
# 28        abysmally
# 29            abyss
# ...             ...
# 4753          wrath
# 4754          wreak
# 4755        wreaked
# 4756         wreaks
# 4757          wreck
# 4758          wrest
# 4759        wrestle
# 4760         wretch
# 4761       wretched
# 4762     wretchedly
# 4763   wretchedness
# 4764        wrinkle
# 4765       wrinkled
# ...

# %%
b.to_csv('MPQA_NEG_DIC.csv', encoding='utf-8')

# %% [markdown]
# ## 긍정 + 부정

# %%
a['Tag'] = 'POS'

# %%
a.columns = ["word", "Tag"]

# %%
a
# Out:
#                  word  Tag
# 0                  a+  POS
# 1              abound  POS
# 2             abounds  POS
# 3           abundance  POS
# 4            abundant  POS
# 5          accessable  POS
# 6          accessible  POS
# 7             acclaim  POS
# 8           acclaimed  POS
# 9         acclamation  POS
# 10           accolade  POS
# 11          accolades  POS
# 12      accommodative  POS
# 13       accomodative  POS
# 14         accomplish  POS
# 15       accomplished  POS
# 16     accomplishment  POS
# 17    accomplishments  POS
# 18           accurate  POS
# 19         accurately  POS
# 20         achievable  POS
# 21        achievement  POS
# 22       achievements  POS
# 23         achievible  POS
# 24             acumen  POS
# 25          adaptable  POS
# 26           adaptive  POS
# 27           adequate  POS
# 28         adjustable  POS
# 29          admirable  POS
# ...               ...  ...
# 1976            witty  POS
# 1977              won  POS
# ...

# %%
b['Tag'] = 'NEG'

# %%
b.columns = ["word", "Tag"]

# %%
b
# Out:
#                word  Tag
# 0           2-faced  NEG
# 1           2-faces  NEG
# 2          abnormal  NEG
# 3           abolish  NEG
# 4        abominable  NEG
# 5        abominably  NEG
# 6         abominate  NEG
# 7       abomination  NEG
# 8             abort  NEG
# 9           aborted  NEG
# 10           aborts  NEG
# 11           abrade  NEG
# 12         abrasive  NEG
# 13           abrupt  NEG
# 14         abruptly  NEG
# 15          abscond  NEG
# 16          absence  NEG
# 17    absent-minded  NEG
# 18         absentee  NEG
# 19           absurd  NEG
# 20        absurdity  NEG
# 21         absurdly  NEG
# 22       absurdness  NEG
# 23            abuse  NEG
# 24           abused  NEG
# 25           abuses  NEG
# 26          abusive  NEG
# 27          abysmal  NEG
# 28        abysmally  NEG
# 29            abyss  NEG
# ...             ...  ...
# 4753          wrath  NEG
# 4754          wreak  NEG
# 4755        wreaked  NEG
# 4756         wreaks  NEG
# 4757          wreck  NEG
# ...

# %%
total = a.append(b, ignore_index = True)

# %%
total.to_csv('MPQA_total_DIC.csv', encoding='utf-8')

# %%
total
# Out:
#                  word  Tag
# 0                  a+  POS
# 1              abound  POS
# 2             abounds  POS
# 3           abundance  POS
# 4            abundant  POS
# 5          accessable  POS
# 6          accessible  POS
# 7             acclaim  POS
# 8           acclaimed  POS
# 9         acclamation  POS
# 10           accolade  POS
# 11          accolades  POS
# 12      accommodative  POS
# 13       accomodative  POS
# 14         accomplish  POS
# 15       accomplished  POS
# 16     accomplishment  POS
# 17    accomplishments  POS
# 18           accurate  POS
# 19         accurately  POS
# 20         achievable  POS
# 21        achievement  POS
# 22       achievements  POS
# 23         achievible  POS
# 24             acumen  POS
# 25          adaptable  POS
# 26           adaptive  POS
# 27           adequate  POS
# 28         adjustable  POS
# 29          admirable  POS
# ...               ...  ...
# 6759            wrath  NEG
# 6760            wreak  NEG
# ...
